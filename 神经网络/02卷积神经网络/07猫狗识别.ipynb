# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import sklearn
import pandas as pd
import os
import sys
import time
import tensorflow as tf

from tensorflow import keras

# %% [markdown]
# ### 加载图片

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1./255)

training_set = train_datagen.flow_from_directory(
    'D:/project/dataset/cat_and_dog/training_set', 
    target_size=(50, 50), 
    batch_size=32, 
    class_mode='binary')

test_set = train_datagen.flow_from_directory(
    'D:/project/dataset/cat_and_dog/test_set', 
    target_size=(50, 50), 
    batch_size=32, 
    class_mode='binary')
# Out:
# Found 8005 images belonging to 2 classes.
# Found 2023 images belonging to 2 classes.

# %% [markdown]
# ### 建立cnn模型

# %% [markdown]
# ![image.png](attachment:68c3bf0e-b401-43b7-945f-13b508f3de01.png)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense

model = Sequential()
# 卷积层
model.add(Conv2D(32, (3,3), input_shape=(50,50,3), activation='relu'))
# 池化层
model.add(MaxPool2D(pool_size=(2,2)))
# 卷积层
model.add(Conv2D(32, (3,3), activation='relu'))
# 池化层
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(units=128, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))

# %% [markdown]
# ## 配置模型

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 48, 48, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 24, 24, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 22, 22, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 11, 11, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 3872)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               495744
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 506,017
# Trainable params: 506,017
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 训练模型

# %%
# %%time
history = model.fit_generator(training_set, epochs=20)
# Out:
# WARNING:tensorflow:From <timed exec>:1: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/20
# 251/251 [==============================] - 17s 66ms/step - loss: 0.6717 - accuracy: 0.5865
# Epoch 2/20
# 251/251 [==============================] - 17s 66ms/step - loss: 0.5825 - accuracy: 0.6968
# Epoch 3/20
# 251/251 [==============================] - 17s 66ms/step - loss: 0.5187 - accuracy: 0.7400
# Epoch 4/20
# 251/251 [==============================] - 16s 66ms/step - loss: 0.4723 - accuracy: 0.77400s - loss: 0.4
# Epoch 5/20
# 251/251 [==============================] - 16s 66ms/step - loss: 0.4197 - accuracy: 0.8067
# Epoch 6/20
# 251/251 [==============================] - 17s 66ms/step - loss: 0.3857 - accuracy: 0.8245
# Epoch 7/20
# 251/251 [==============================] - 16s 66ms/step - loss: 0.3350 - accuracy: 0.8511
# Epoch 8/20
# 251/251 [==============================] - 17s 66ms/step - loss: 0.2792 - accuracy: 0.8806
# Epoch 9/20
# 251/251 [==============================] - 16s 66ms/step - loss: 0.2171 - accuracy: 0.9118
# Epoch 10/20
# 251/251 [==============================] - 16s 66ms/step - loss: 0.1630 - accuracy: 0.9384
# Epoch 11/20
# 251/251 [==============================] - 17s 66ms/step - loss: 0.1205 - accuracy: 0.9578
# Epoch 12/20
# 251/251 [==============================] - 17s 66ms/step - loss: 0.0797 - accuracy: 0.9733
# Epoch 13/20
# 251/251 [==============================] - 17s 66ms/step - loss: 0.0441 - accuracy: 0.9881
# Epoch 14/20
# 251/251 [==============================] - 16s 66ms/step - loss: 0.0312 - accuracy: 0.9929
# Epoch 15/20
# 251/251 [==============================] - 16s 66ms/step - loss: 0.0196 - accuracy: 0.9966
# Epoch 16/20
# 251/251 [==============================] - 17s 66ms/step - loss: 0.0191 - accuracy: 0.9960
# Epoch 17/20
# 251/251 [==============================] - 17s 66ms/step - loss: 0.0078 - accuracy: 0.9998
# Epoch 18/20
# 251/251 [==============================] - 16s 66ms/step - loss: 0.0035 - accuracy: 0.9998
# Epoch 19/20
# 251/251 [==============================] - 16s 66ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 20/20
# 251/251 [==============================] - 16s 65ms/step - loss: 8.8554e-04 - accuracy: 1.0000
# Wall time: 5min 32s

# %%
def plot_learning_curves(history):
    pd.DataFrame(history.history).plot(figsize=(8, 5))
    plt.grid(True)
    plt.gca().set_ylim(0, 1)
    plt.show()

plot_learning_curves(history)

# %%
accuracy_train = model.evaluate_generator(training_set)
print(accuracy_train[1])
# Out:
# 1.0

# %%
accuracy_test = model.evaluate_generator(test_set)
print(accuracy_test[1])
# Out:
# 0.7602570652961731

# %% [markdown]
# ## 用一张图片进行验证

# %%
training_set.class_indices
# Out:
# {'cats': 0, 'dogs': 1}

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array

pic_dog = 'D:/project/dataset/cat_and_dog/valid01.jpg'
pic_dog = load_img(pic_dog, target_size=(50,50))
pic_dog = img_to_array(pic_dog)
pic_dog = pic_dog / 255
pic_dog = pic_dog.reshape(1,50,50,3)
result = model.predict_classes(pic_dog)
print(result)
# Out:
# [[0]]

# %%
pic_cat = 'D:/project/dataset/cat_and_dog/valid05.jpg'
pic_cat = load_img(pic_cat, target_size=(50,50))
pic_cat = img_to_array(pic_cat)
pic_cat = pic_cat / 255
pic_cat = pic_cat.reshape(1,50,50,3)
result2 = model.predict_classes(pic_cat)
print(result2)
# Out:
# [[0]]

# %%
import matplotlib as mlp
font2 = {'family': 'SimHei',
         'weight': 'normal',
         'size': 20}
mlp.rcParams['font.family'] = 'SimHei'
mlp.rcParams['axes.unicode_minus'] = False

from matplotlib.image import imread
from tensorflow.keras.models import load_model

a = [i for i in range(1, 10)]
fig = plt.figure(figsize=(10, 10))

for i in a:
    img_name = 'D:/project/dataset/cat_and_dog/' + str(i) + '.jpg'
    img_ori = load_img(img_name, target_size=(50, 50))
    img = img_to_array(img_ori)
    img = img.astype('float32') / 255
    img = img.reshape(1, 50, 50, 3)
    result = model.predict_classes(img)
    img_ori = load_img(img_name, target_size=(250, 250))
    plt.subplot(3, 3, i)
    plt.imshow(img_ori)
    plt.title('预测为：狗狗' if result[0][0] == 1 else '预测为：猫猫')
    
plt.show()
